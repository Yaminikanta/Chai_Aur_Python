# %% [markdown]
# #### Dictionaty

# %%
chai_types = {"Masala": 'Spicy', "Ginger": 'Zesty', "Green": 'Mild'}
chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'Zesty', 'Green': 'Mild'}

# %%
chai_types['Masala']
# Out:
# 'Spicy'

# %%
chai_types.get("Masala")
# Out:
# 'Spicy'

# %%
chai_types['Green'] = "Fresh"

chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'Zesty', 'Green': 'Fresh'}

# %%
# to access key
for i in chai_types:
    print(i)
# Out:
# Masala
# Ginger
# Green

# %%
# to access value
for i in chai_types:
    print(chai_types[i])
# Out:
# Spicy
# Zesty
# Fresh

# %%
for i in chai_types:
    print(i ,chai_types[i])
# Out:
# Masala Spicy
# Ginger Zesty
# Green Fresh

# %%
for key, value in chai_types.items():
    print(key, value)
# Out:
# Masala Spicy
# Ginger Zesty
# Green Fresh

# %%
if "Masala" in chai_types:
    print("i have masala chai")
# Out:
# i have masala chai

# %%
chai_types["Earl Gray"] = "Citrus"
chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'Zesty', 'Green': 'Fresh', 'Earl Gray': 'Citrus'}

# %%
chai_types.pop('Ginger')
# Out:
# 'Zesty'

# %%
chai_types
# Out:
# {'Masala': 'Spicy', 'Green': 'Fresh', 'Earl Gray': 'Citrus'}

# %%
chai_types.popitem()
# Out:
# ('Earl Gray', 'Citrus')

# %%
chai_types
# Out:
# {'Masala': 'Spicy', 'Green': 'Fresh'}

# %%
del chai_types["Green"]
chai_types
# Out:
# {'Masala': 'Spicy'}

# %%
chai_types_copy =chai_types.copy()
print(chai_types, id(chai_types))
print(chai_types_copy, id(chai_types_copy))
# Out:
# {'Masala': 'Spicy'} 2262906680768
# {'Masala': 'Spicy'} 2262906668352

# %%
tea_shop = {
    "chai" : {"Masala": 'Spicy', "Ginger": 'Zesty'},
    "tea" : {"Green": 'Mild', "Black": 'Strong'}
}
tea_shop
# Out:
# {'chai': {'Masala': 'Spicy', 'Ginger': 'Zesty'},
#  'tea': {'Green': 'Mild', 'Black': 'Strong'}}

# %%
tea_shop["chai"]
# Out:
# {'Masala': 'Spicy', 'Ginger': 'Zesty'}

# %%
tea_shop["chai"]['Ginger']
# Out:
# 'Zesty'

# %%
sqr_num = { x: x**2 for x in range(6)}
sqr_num
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
