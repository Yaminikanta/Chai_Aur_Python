# %% [markdown]
# ### Strings

# %%
chai = 'masala chai'
first_char = chai[0]
print(first_char)
# Out:
# m

# %%
sliced_chai =chai[0:6]
print(sliced_chai)

print(chai[-1])             # gives last chat
# Out:
# masala
# i

# %%
num_list = '0123456789'
print(num_list)
print(num_list[:])
print(num_list[3:])
print(num_list[:7])
print(num_list[0:7:2])
print(num_list[0:7:3])
# Out:
# 0123456789
# 0123456789
# 3456789
# 0123456
# 0246
# 036

# %%
print(chai)
print(chai.lower())
print(chai.upper())
# Out:
# masala chai
# masala chai
# MASALA CHAI

# %%
chai = '       masala chai       '
print(chai)
print(chai.strip())
# Out:
#        masala chai
# masala chai

# %%
chai = 'Lemon chai'
print(chai)

print(chai.replace('Lemon', 'Ginger'))
print(chai)
# Out:
# Lemon chai
# Ginger chai
# Lemon chai

# %%
chai = 'lemon ginger masala mint'
print(chai)
print(chai.split())
# Out:
# lemon ginger masala mint
# ['lemon', 'ginger', 'masala', 'mint']

# %%
chai =  'Masala Chai'
print(chai.find('Chai'))
print(chai.find('chai'))
# Out:
# 7
# -1

# %%
chai = 'masala'
quantity = 5

print(f'i order {quantity} cups of {chai} chai')
# Out:
# i order 5 cups of masala chai
