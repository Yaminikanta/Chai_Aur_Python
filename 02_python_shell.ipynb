# %%
print("chai")
# Out:
# chai

# %%
"chai" * 4
# Out:
# 'chaichaichaichai'

# %%
score = 100
score
# Out:
# 100

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\yamin\\Desktop\\Chai_Aur_Python'

# %%
for c in "chai":
    print(c)
# Out:
# c
# h
# a
# i

# %%
import sys
sys.platform
# Out:
# 'win32'
