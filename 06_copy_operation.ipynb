# %% [markdown]
# ## Copy Operation

# %%
"""
->A copy operation in Python means creating a new variable or object based on an existing one so that data can be reused without
(or with limited) shared memory.

-> It is of 3 types
1) normal copy
2) shallow copy
3) deep copy

"""
# Out:
# '\n->A copy operation in Python means creating a new variable or object based on an existing one so that data can be reused without\n(or with limited) shared memory.\n\n-> It is of 3 types\n1) normal copy\n2) shallow copy\n3) deep copy\n\n'

# %%
"""
Normal copy:- 
In it we will see how Normal copy works using id, its drop back and how to over come it

In it we see when we copy a value from source variable(a) to destination variable(b) along with value the reference id also copied
and if we change anything in any variable the other variable also got changed which is not good 
means here Only reference is copied and Changes reflect in both variables

to over come this problem we will use shallow copy

"""
a = [1, 2, 3]
b = a
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')

a[0] = 11
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')

b[1] = 22
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b))
# Out:
# a =  [1, 2, 3] , id- 2444480043584
# b =  [1, 2, 3] , id- 2444480043584
#
# a =  [11, 2, 3] , id- 2444480043584
# b =  [11, 2, 3] , id- 2444480043584
#
# a =  [11, 22, 3] , id- 2444480043584
# b =  [11, 22, 3] , id- 2444480043584

# %%
"""
Shallow copy:-
In it A new outer object is created, but inner objects are shared.

to use it we have to import copy module or we can use slice

in the below example we can see both a and b have different ref id with same value and when we change value using indexing to does not 
impact other variable

"""
# using copy module

import copy

a = [1, 2, 3]
b = copy.copy(a)
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')

a[0] = 11
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')

b[1] = 22
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b))
# Out:
# a =  [1, 2, 3] , id- 2444480161344
# b =  [1, 2, 3] , id- 2444480001920
#
# a =  [11, 2, 3] , id- 2444480161344
# b =  [1, 2, 3] , id- 2444480001920
#
# a =  [11, 2, 3] , id- 2444480161344
# b =  [1, 22, 3] , id- 2444480001920

# %%
# using slice

a = [1, 2, 3, 4, 5]
b = a[:]
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')

a[0] = 10
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')

b[1] = 20
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b))
# Out:
# a =  [1, 2, 3, 4, 5] , id- 2444480161536
# b =  [1, 2, 3, 4, 5] , id- 2444480039616
#
# a =  [10, 2, 3, 4, 5] , id- 2444480161536
# b =  [1, 2, 3, 4, 5] , id- 2444480039616
#
# a =  [10, 2, 3, 4, 5] , id- 2444480161536
# b =  [1, 20, 3, 4, 5] , id- 2444480039616

# %%
"""
but there is a problem in shallow copy when we work with nested data when values are same it got same reference id
and bcz of same reference id and its mutable so when we change value in 'a' it reflects with 'b' also and vice versa

so to over come this problem we will use deep copy in next step
"""
import copy

a = [[1, 2, 3], [4, 5, 6]]
b = copy.copy(a)
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')      

print('a[0] = ', a[0], ', id-', id(a[0]),  ', a[1] = ', a[1], id(a[1]))
print('b[0] = ', b[0], ', id-', id(b[0]),  ', b[1] = ', b[1], id(b[1]), '\n')

a[0][0] = 10
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')

b[1][0] = 40
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')

print('a[0] = ', a[0], ', id-', id(a[0]),  ', a[1] = ', a[1], id(a[1]))
print('b[0] = ', b[0], ', id-', id(b[0]),  ', b[1] = ', b[1], id(b[1]))
# Out:
# a =  [[1, 2, 3], [4, 5, 6]] , id- 2444480226816
# b =  [[1, 2, 3], [4, 5, 6]] , id- 2444480227264
#
# a[0] =  [1, 2, 3] , id- 2444480226880 , a[1] =  [4, 5, 6] 2444480226944
# b[0] =  [1, 2, 3] , id- 2444480226880 , b[1] =  [4, 5, 6] 2444480226944
#
# a =  [[10, 2, 3], [4, 5, 6]] , id- 2444480226816
# b =  [[10, 2, 3], [4, 5, 6]] , id- 2444480227264
#
# a =  [[10, 2, 3], [40, 5, 6]] , id- 2444480226816
# b =  [[10, 2, 3], [40, 5, 6]] , id- 2444480227264
#
# a[0] =  [10, 2, 3] , id- 2444480226880 , a[1] =  [40, 5, 6] 2444480226944
# b[0] =  [10, 2, 3] , id- 2444480226880 , b[1] =  [40, 5, 6] 2444480226944

# %%
"""
Deep Copy:-
In it all nested value along with whole variable also got different memory space so,
when we change any value in any position it does not impact to other variable

"""
import copy

a = [[1, 2, 3, 4], [5, 6, 7, 8]]
b = copy.deepcopy(a)

print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')      

print('a[0] = ', a[0], ', id-', id(a[0]),  ', a[1] = ', a[1], id(a[1]))
print('b[0] = ', b[0], ', id-', id(b[0]),  ', b[1] = ', b[1], id(b[1]), '\n')

a[0][0] = 10
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')

b[1][0] = 50
print('a = ',a, ', id-', id(a))
print('b = ',b, ', id-', id(b),'\n')

print('a[0] = ', a[0], ', id-', id(a[0]),  ', a[1] = ', a[1], id(a[1]))
print('b[0] = ', b[0], ', id-', id(b[0]),  ', b[1] = ', b[1], id(b[1]))
# Out:
# a =  [[1, 2, 3, 4], [5, 6, 7, 8]] , id- 2444480225792
# b =  [[1, 2, 3, 4], [5, 6, 7, 8]] , id- 2444480161536
#
# a[0] =  [1, 2, 3, 4] , id- 2444480225728 , a[1] =  [5, 6, 7, 8] 2444480226368
# b[0] =  [1, 2, 3, 4] , id- 2444480225920 , b[1] =  [5, 6, 7, 8] 2444480156480
#
# a =  [[10, 2, 3, 4], [5, 6, 7, 8]] , id- 2444480225792
# b =  [[1, 2, 3, 4], [5, 6, 7, 8]] , id- 2444480161536
#
# a =  [[10, 2, 3, 4], [5, 6, 7, 8]] , id- 2444480225792
# b =  [[1, 2, 3, 4], [50, 6, 7, 8]] , id- 2444480161536
#
# a[0] =  [10, 2, 3, 4] , id- 2444480225728 , a[1] =  [5, 6, 7, 8] 2444480226368
# b[0] =  [1, 2, 3, 4] , id- 2444480225920 , b[1] =  [50, 6, 7, 8] 2444480156480
