# %%
tea_type = ("black", "green", "oolang")
tea_type
# Out:
# ('black', 'green', 'oolang')

# %%
tea_type[0]
# Out:
# 'black'

# %%
tea_type[-1]
# Out:
# 'oolang'

# %%
tea_type[1:]
# Out:
# ('green', 'oolang')

# %%
# tea_type[0] = "lemon"                 # will throw error

# %%
len(tea_type)
# Out:
# 3

# %%
more_tea = ("herbal", "earl grey")
all_tea = more_tea + tea_type
all_tea
# Out:
# ('herbal', 'earl grey', 'black', 'green', 'oolang')

# %%
if 'green' in all_tea:
    print("i have green tea")
# Out:
# i have green tea

# %%
more_tea = ("herbal", "earlgrey", "herbal")
more_tea
# Out:
# ('herbal', 'earlgrey', 'herbal')

# %%
more_tea.count('herbal')
# Out:
# 2

# %%
more_tea.count('herballl')
# Out:
# 0

# %%
tea_type
# Out:
# ('black', 'green', 'oolang')

# %%
(Black, Green, Oolang) = tea_type

# %%
print(Black)
print(Green)
print(Oolang)
# Out:
# black
# green
# oolang

# %%
type(tea_type)
# Out:
# tuple

# %%
type(Black)
# Out:
# str

# %%
t1 = ("string", (1,2,3), "tuple")
t1
# Out:
# ('string', (1, 2, 3), 'tuple')
