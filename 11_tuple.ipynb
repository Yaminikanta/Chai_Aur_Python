# %%
tea_type = ("black", "green", "oolang")
tea_type
# Out:
# ('black', 'green', 'oolang')

# %%
tea_type[0]
# Out:
# 'black'

# %%
tea_type[-1]
# Out:
# 'oolang'

# %%
tea_type[1:]
# Out:
# ('green', 'oolang')
