# %% [markdown]
# ### numpy

# %%
import numpy as np 

a=[1,2,3,4,5,6]
arr1=np.array(a)
# print(arr1.reshape(1,6))
# print(arr1.reshape(2,3))
print(arr1.reshape(3,2))
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
