# %% [markdown]
# ### mutable and immutable

# %%
"""
Mutable:-
1)List
2)Set
3)Dictionary
4)ByteArray
5)Array

Immutable:-
1)Integer
2)Float
3)Boolean
4)String
5)Tuple
6)Frozen Set
7)Bytes

"""

# %%
username = "yamini kant"
username
# Out:
# 'yamini kant'

# %%
username = 'chai aur code'
username
# Out:
# 'chai aur code'

# %%
x = 10
y = x 
x
# Out:
# 10

# %%
y
# Out:
# 10

# %%
x = 15
y
# Out:
# 10
